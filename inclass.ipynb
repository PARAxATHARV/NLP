# %%
import spacy


nlp = spacy.load("en_core_web_sm")
text = "unfortunately your application has been rejected "

doc = nlp(text)

for token in doc:
    print(
        f"{token.text:<15}"
        f"{token.text:<15}"
        f"{token.head.text}"
    )
# Out:
# unfortunately  unfortunately  rejected
# your           your           application
# application    application    rejected
# has            has            rejected
# been           been           rejected
# rejected       rejected       rejected

# %%
from spacy import displacy
play = displacy.render(doc,style="dep",jupyter=True)
display(play)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9cf9210cbf7e4b85836d661a1fcaa308-0" class="displacy" width="1100" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">unfortunately</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
import spacy


nlp = spacy.load("en_core_web_sm")
text = "apple opened ioffice in california in 2025 "

#doc = nlp(text)

for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# apple ORG
# california GPE
# 2025 DATE

# %%
text = """"
Microsoft announced that it will invest 3 billions in germany by 2026.  
The project support AI research in berlin and munich .
Satya  nadella said the company wants to exand cloud infrastructure in europe.
"""
doc = nlp(text)

for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# Microsoft ORG
# 3 billions MONEY
# germany GPE
# 2026 DATE
# AI GPE
# berlin GPE
# munich GPE
# Satya GPE
# nadella PERSON
# europe LOC

# %%
from scipy.spatial import distance 
string_1="test"
string_2="text"

hamming_distance = distance.hamming(
    list(string_1),
         list(string_2)
         )
AD = hamming_distance*len(string_1)

# %%
import Levenshtein 
from scipy.spatial import distance 
string_1="kitten"
string_2="sitting"

lv = Levenshtein.distance(string_1,string_2)
print('Levenshtein: ',lv)
# Out:
# Levenshtein:  3

# %%
#jaccard similarity
doc1 = "I love natural language processing"
doc2 = "I love machine learning"
 
words1= doc1.lower().split()
words2= doc2.lower().split()
 
set1 = set(words1)
set2 = set(words2)
 
intersection = set1.intersection(set2)
union = set1.union(set2)
jaccard_similarity = len(intersection) / len(union)
print(f"Jaccard Similarity: {jaccard_similarity}")
# Out:
# Jaccard Similarity: 0.2857142857142857

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
 
documents = [
    "I love natural language processing",
    "I love machine learning",
    "Machine Learning is powerful"]
 
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)
print("vocabulary:")
print(vectorizer.get_feature_names_out())
print("TF-IDF Matrix:")
# Out:
# vocabulary:
# ['is' 'language' 'learning' 'love' 'machine' 'natural' 'powerful'
#  'processing']
# TF-IDF Matrix:

# %%
from sklearn.metrics.pairwise import cosine_similarity
 
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)
 
similarity_matrix = cosine_similarity(tfidf_matrix)
similarity_score = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
print(f"Cosine Similarity between doc1 and doc2: {similarity_score[0,0]}")
print("Cosine Similarity Matrix:")
print(similarity_matrix)
# Out:
# Cosine Similarity between doc1 and doc2: 0.23211804319157203
# Cosine Similarity Matrix:
# [[1.         0.23211804 0.        ]
#  [0.23211804 1.         0.49426499]
#  [0.         0.49426499 1.        ]]
