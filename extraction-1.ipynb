# %%
import spacy
from spacy import displacy
from IPython.display import HTML, display

#   Load the English language model
nlp = spacy.load("en_core_web_sm")

text = "I saw the man with a telescope."

doc = nlp(text)

# Print the dependency parse information for each token
for token in doc:
    print(f"{token.text:<12} {token.dep_:<12} {token.head.text}")

html = displacy.render(doc, style="dep", jupyter=False)

# Display the dependency parse visualization in Jupyter Notebook
display(HTML(html))

# Discuss with your partner:
# 1. What is the ROOT?
  #---- saw is the root 
# 2. What does "with a telescope" modify?
#----it modifies the meaning of man's position 
# 3. Does the sentence have more than one meaning?
    #---Yes.
# 4. Did spaCy choose the interpretation you expected?
#yes 
# 5. Rewrite the sentence to remove ambiguity.
#Using a telescope, I saw the man
# Out:
# I            nsubj        saw
# saw          ROOT         saw
# the          det          man
# man          dobj         saw
# with         prep         saw
# a            det          telescope
# telescope    pobj         with
# .            punct        saw
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d0cbb65069d34c08982900a95bf39cfa-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">saw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">man</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">telescope.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d0cbb65069d34c08982900a95bf39cfa-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d0cbb65069d34c08982900a95bf39cfa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d0cbb65069d34c08982900a95bf39cfa-0-1" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d0cbb65069d34c08982900a95bf39cfa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d0cbb65069d34c08982900a95bf39cfa-0-2" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d0cbb65069d34c08982900a95bf39cfa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,266.5 L578.0,254.5 562.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d0cbb65069d34c08982900a95bf39cfa-0-3" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d0cbb65069d34c08982900a95bf39cfa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d0cbb65069d34c08982900a95bf39cfa-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d0cbb65069d34c08982900a95bf39cfa-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d0cbb65069d34c08982900a95bf39cfa-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d0cbb65069d34c08982900a95bf39cfa-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
# </svg>

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = """
Microsoft announced a new AI research initiative
in Berlin on 15 June 2026.

The project involves collaboration with Google,
SAP and SRH University Heidelberg.

Satya Nadella will present the initiative
at a conference in Germany.
"""

doc = nlp(text)

for ent in doc.ents:
    print(
        ent.text,
        ent.label_,
        spacy.explain(ent.label_)
    )

#1. Which entities were detected?
"""Microsoft 
Berlin 
15 June 2026 DATE 
Google 
SAP 
Satya Nadella 
Germany
#2. Which labels were assigned?

#3. Which entity types occur most often?
#4. Were any entities missed?"""
     
#2. Which labels were assigned?
""""Microsoft                 ORG

Berlin                    GPE

15 June 2026              DATE

Google                    ORG

SAP                        ORG

SRH University Heidelberg ORG

Satya Nadella             PERSON

Germany                   GPE"""
#3. Which entity types occur most often?
# ORG (Organization)
#4. Were any entities missed?
#AI research initiative
# Out:
# Microsoft ORG Companies, agencies, institutions, etc.
# AI ORG Companies, agencies, institutions, etc.
# Berlin GPE Countries, cities, states
# 15 June 2026 DATE Absolute or relative dates or periods
# Google ORG Companies, agencies, institutions, etc.
# SAP ORG Companies, agencies, institutions, etc.
# Satya Nadella PERSON People, including fictional
# Germany GPE Countries, cities, states

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "AI is transforming healthcare",
    "Machine learning improves healthcare",
    "Football is a popular sport"
]

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

print("Vocabulary:")
print(vectorizer.get_feature_names_out())

print("\nTF-IDF Matrix:")
print(tfidf_matrix.toarray())

similarity_matrix = cosine_similarity(tfidf_matrix)

print("\nCosine Similarity Matrix:")
print(similarity_matrix)

print("Doc1 vs Doc2:", round(similarity_matrix[0][1], 3))
print("Doc1 vs Doc3:", round(similarity_matrix[0][2], 3))
print("Doc2 vs Doc3:", round(similarity_matrix[1][2], 3))

""""# 1. Which pair has the highest similarity?
healthcare
# 2. Is this result reasonable?
doc 1 - AI is transforming healthcare
doc2 - Machine learning improves healthcare
# 3. Why does TF-IDF treat some words as more important?
gives importance to frequent in one document but are less importance to less frequent in others 
# 4. Does cosine understand meaning?
Cosine similarity only compares vector values. It checks how similar the word patterns are
# 5. Would it know that "AI" and "machine learning" are related?
no it wont understand 
"""
# Out:
# Vocabulary:
# ['ai' 'football' 'healthcare' 'improves' 'is' 'learning' 'machine'
#  'popular' 'sport' 'transforming']
#
# TF-IDF Matrix:
# [[0.5628291  0.         0.42804604 0.         0.42804604 0.
#   0.         0.         0.         0.5628291 ]
#  [0.         0.         0.40204024 0.52863461 0.         0.52863461
#   0.52863461 0.         0.         0.        ]
#  [0.         0.52863461 0.         0.         0.40204024 0.
#   0.         0.52863461 0.52863461 0.        ]]
#
# Cosine Similarity Matrix:
# [[1.         0.17209173 0.17209173]
#  [0.17209173 1.         0.        ]
#  [0.17209173 0.         1.        ]]
# Doc1 vs Doc2: 0.172
# Doc1 vs Doc3: 0.172
# Doc2 vs Doc3: 0.0
# '"# 1. Which pair has the highest similarity?\nhealthcare\n# 2. Is this result reasonable?\ndoc 1 - AI is transforming healthcare\ndoc2 - Machine learning improves healthcare\n# 3. Why does TF-IDF treat some words as more important?\ngives importance to frequent in one document but are less importance to less frequent in others \n# 4. Does cosine understand meaning?\nCosine similarity only compares vector values. It checks how similar the word patterns are\n# 5. Would it know that "AI" and "machine learning" are related?\nno it wont understand \n'
